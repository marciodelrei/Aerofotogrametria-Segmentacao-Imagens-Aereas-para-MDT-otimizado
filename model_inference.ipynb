# %% [markdown]
# # Using Image Masks
#
# *https://docs.opendronemap.org/masks/*
#
# Starting from ODM 2.0 people can supply image masks to inform the software to skip reconstruction over certain areas. This is useful for cases where the sky was accidentally included in the input photos from oblique shots, or simply to limit the reconstruction of a single subject.
#
# To add a mask, simply create a new black and white image of the same dimension as the target image you want to mask (you can use a program such as GIMP to do this). Color in black the areas to exclude from the reconstruction.
#
# Name your file:
#
# \<filename\>_mask.JPG
#
# For example, DJI_0018.JPG can have a mask by creating a DJI_0018_mask.JPG file and include that in the list of images.
#
# You can use .JPG, .PNG, .BMP and .TIF formats for image masks.

# %%
import os
from glob import glob
from datetime import datetime
import numpy as np
import pickle
from tqdm import tqdm
import matplotlib.pyplot as plt 
# %matplotlib inline 

from PIL import Image

import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate

# from tensorflow.keras.preprocessing.image import array_to_img

# %%
images_path = r"fotos"
mask_inference_path = r"masked_inference"
mask_inference_resized_path = r"masked_inference_resized"
mask_suffix = "_mask"

# %%
def create_dir(dir_path):
    if not os.path.isdir(dir_path):
        os.makedirs(dir_path)
        # print(f"create_dir: {dir_path}")
       

def get_name_mask_inferenced(image_name):
    base_dir = os.path.dirname(image_name)
    base_name = os.path.basename(image_name)
    nomes = base_name.split(os.extsep)
    base_nameflie = nomes[0]
    extension = nomes[1]
    retorno = os.path.join(base_dir, base_nameflie + mask_suffix + os.path.extsep + extension)
    # print(f"get_name_mask_inferenced: {retorno}")
    return retorno


def get_fmtedDateTime():
    fmtedDateTime = datetime.now().strftime('%Y%m%d%H%M%S')
    retorno = fmtedDateTime
    # print(f"get_fmtedDateTime: {retorno}")
    return retorno


def process_path(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img,channels=3)
    img = tf.image.convert_image_dtype(img,tf.float32) #this do the same as dividing by 255 to set the values between 0 and 1 (normalization)
    # print(f"process_path: {True}")
    return img


def preprocess_image(image):
    input_image = tf.image.resize(image,(96,128),method='nearest')
    preprocessed_image = input_image
    # print(f"preprocess_image: {True}")
    return preprocessed_image


def inference(model, image):
    predictions = model.predict(np.expand_dims(image, axis=0))
    # print(f"inference: {True}" )
    return predictions


def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    # print(f"create_mask: {True}")
    return pred_mask[0]


def reprocess_image(mask_inferenced):
    # image_reduced = tf.math.reduce_max(mask_inferenced, axis=-1, keepdims=True)
    output_image = tf.image.resize(mask_inferenced,(3000,4000),method='nearest')
    reprocessed_mask = create_mask(output_image)
    # print(f"reprocess_image: {True}")
    return reprocessed_mask

def image_resize(image_tensor):
    # print(f"image_tensor.shape: {image_tensor.shape}" )
    # Assuming you have an image tensor with shape (1, 96, 128, 23)
    # Reshape the image tensor to (96, 128, 23)
    image_tensor_reshaped = tf.reshape(image_tensor, (96, 128, 23))
    # print(f"image_tensor_reshaped.shape: {image_tensor_reshaped.shape}" )

    # Expand the dimensions to (1, 96, 128, 23, 1)
    expanded_image_tensor = tf.expand_dims(image_tensor_reshaped, axis=-1)
    # print(f"expanded_image_tensor.shape: {expanded_image_tensor.shape}" )

    # Resize the image tensor to the desired shape (3000, 4000, 1)
    resized_image = tf.image.resize(expanded_image_tensor, (3000, 4000), method=tf.image.ResizeMethod.BILINEAR)
    # print(f"resized_image.shape: {resized_image.shape}" )

    # Remove the extra dimension to obtain (3000, 4000, 1)
    resized_image = tf.squeeze(resized_image, axis=0)
    # print(f"resized_image.shape: {resized_image.shape}" )

    return resized_image


def save_mask_inference(mask_resized):
    # print(f"save_mask_inference: {mask_inference_path}" )
    pass


def display(display_list):
    plt.figure(figsize=(20, 15))

    title = ['Input Image', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        # plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.imshow(display_list[i])
        plt.axis('off')
    plt.show()


def create_binary_segmentation_problem(image_dataset, mask_dataset):
    # change problem to binary segmentation problem
    x_reduced, y_reduced = [], []

    # iterate over masks
    for j, mask in tqdm(enumerate(mask_dataset)):

        # get image shape
        _img_height, _img_width, _img_channels = mask.shape

        # create binary image (zeros)
        binary_image = np.zeros((_img_height, _img_width, 1)).astype(int)

        # iterate over each pixel in mask
        for row in range(_img_height):
            for col in range(_img_width):
                # get image channel across axis=3
                rgb = mask[row, col, :]

                # building hex: #3C1098 = RGB(60, 16, 152) or BGR(152, 16, 60)
                binary_image[row, col] = 1 if rgb[0] == 60 and rgb[1] == 16 and rgb[2] == 152 else 0

        # only keep images with a high percentage of building coverage
        if np.count_nonzero(binary_image == 1) > 0.15 * binary_image.size:
            x_reduced.append(image_dataset[j])
            y_reduced.append(binary_image)

    # return binary image dataset
    return np.array(x_reduced), np.array(y_reduced)

# %%
import os
from glob import glob
from PIL import Image
from enum import Enum

# Classe identificadora de cores classificadas como terreno
class MaskColorMap(Enum):
    unlabeled = (0, 0, 0)
    paved_area = (128, 64, 128)
    dirt = (130, 76, 0)
    grass = (0, 102, 0)
    gravel = (112, 103, 87)
    water = (28, 42, 168)
    rocks = (48, 41, 30)
    pool = (0, 50, 89)
    vegetation = (107, 142, 35)
    roof = (70, 70, 70)
    wall = (102, 102, 156)
    window = (254, 228, 12)
    door = (254, 148, 12)
    fence = (190, 153, 153)
    fence_pole = (153, 153, 153)
    person = (255, 22, 96)
    dog = (102, 51, 0)
    car = (9, 143, 150)
    bicycle = (119, 11, 32)
    tree = (51, 51, 0)
    bald_tree = (190, 250, 190)
    ar_marker = (112, 150, 146)
    obstacle = (2, 135, 115)
    conflicting = (255, 0, 0)

def convert_maskcolor_to_bw(mask_image):
# # old_color = 255, 0, 255, 255
# # black = (0, 0, 0)
# # white = (255, 255, 255)
# terrain_colors = []

    noterrain_colors = []
    noterrain_colors.append(MaskColorMap.unlabeled.value)
    noterrain_colors.append(MaskColorMap.car.value)
    noterrain_colors.append(MaskColorMap.tree.value)
    noterrain_colors.append(MaskColorMap.pool.value)
    noterrain_colors.append(MaskColorMap.roof.value)
    noterrain_colors.append(MaskColorMap.fence_pole.value)
    noterrain_colors.append(MaskColorMap.wall.value)
    noterrain_colors.append(MaskColorMap.door.value)
    noterrain_colors.append(MaskColorMap.window.value)
    noterrain_colors.append(MaskColorMap.obstacle.value)
    noterrain_colors.append(MaskColorMap.vegetation.value)

    # colors_list = []
    # print("Packing colors masks")
    # for j, cls in enumerate(MaskColorMap):
    #     colors_list.append(cls.value)

    black = (0, 0, 0)
    white = (255, 255, 255)

    width, height = mask_image.size

    pix = mask_image.load()
    for x in range(0, width):
        for y in range(0, height):
            color = pix[x,y]

            if color in noterrain_colors:
                mask_image.putpixel((x, y), black)

            else:
                mask_image.putpixel((x, y), white)
                
    im = mask_image.convert('1')
    
    return im

# %%
import os
from glob import glob
from PIL import Image
from enum import Enum

# Classe identificadora de escala de cor preta classificadas como terreno
class MaskGrayMap(Enum):
    terrain_00  = 0
    terrain_01  = 11
    terrain_02  = 12
    terrain_03  = 24
    terrain_04  = 36
    terrain_05  = 48
    terrain_06  = 85
    terrain_07  = 97
    terrain_08  = 109
    terrain_09  = 133
    terrain_10  = 145
    terrain_11  = 218
    terrain_12 = 228
    terrain_13 = 230
    terrain_14 = 240
    terrain_15 = 252



def convert_maskgray_to_bw(mask_image):
    terrain_gray = []
    for _, gray_scale in enumerate(MaskGrayMap):
        terrain_gray.append(gray_scale.value)

    black = 0
    white = 255
    width, height = mask_image.size

    pix = mask_image.load()
    for x in range(0, width):
        for y in range(0, height):
            gray_color = pix[x,y]
            mask_image.putpixel((x, y), white)

            if gray_color not in terrain_gray:
                mask_image.putpixel((x, y), black)

    im = mask_image.convert('1')

    return im

def save_image_crivo(image: Image, percent: int = 15) -> bool:
    save = False
    array = np.array(image)
    mask_px_count = np.count_nonzero(array == 0)
    image_px_total = (image.size[0] * image.size[1])
    mask_percent = (mask_px_count / image_px_total) * 100
    if mask_percent >= percent:
        save = True

    print(f"Mask pixel count: {mask_px_count} | Image pixel total: {image_px_total}")
    print(f"{save}: crivo={percent}%, calculado:{mask_percent}%")
    return save

# %%
create_dir(mask_inference_path)
create_dir(mask_inference_resized_path)

# %%
def conv_block(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    conv = Conv2D(n_filters, 
                  kernel_size = 3,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(inputs)

    conv = Conv2D(n_filters, 
                  kernel_size = 3, 
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(conv)

    if dropout_prob > 0:
        conv = Dropout(dropout_prob)(conv)
        
    if max_pooling:
        next_layer = MaxPooling2D(pool_size=(2,2))(conv)

    else:
        next_layer = conv
        
    skip_connection = conv
    return next_layer, skip_connection


def upsampling_block(expansive_input, contractive_input, n_filters=32):
    up = Conv2DTranspose(
                 n_filters,  
                 kernel_size = 3,
                 strides=(2,2),
                 padding='same')(expansive_input)
    
    merge = concatenate([up, contractive_input], axis=3)
    
    conv = Conv2D(n_filters,  
                 kernel_size = 3,   
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(merge)
    
    conv = Conv2D(n_filters,  
                 kernel_size = 3,  
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(conv)
    return conv


def build_unet_model(input_size=(96, 128, 3), n_filters=32, n_classes=23):
    inputs = Input(input_size)
    
    # contracting path
    cblock1 = conv_block(inputs, n_filters, dropout_prob=0.4)
    cblock2 = conv_block(cblock1[0], 2*n_filters, dropout_prob=0.4)
    cblock3 = conv_block(cblock2[0], 4*n_filters, dropout_prob=0.4)
    cblock4 = conv_block(cblock3[0], 8*n_filters, dropout_prob=0.45) 
    cblock5 = conv_block(cblock4[0],16*n_filters, dropout_prob=0.4, max_pooling=None)     
    
    # expanding path
    ublock6 = upsampling_block(cblock5[0], cblock4[1],  8 * n_filters)
    ublock7 = upsampling_block(ublock6, cblock3[1],  n_filters*4)
    ublock8 = upsampling_block(ublock7,cblock2[1] , n_filters*2)
    ublock9 = upsampling_block(ublock8,cblock1[1],  n_filters)

    conv9 = Conv2D(n_filters,
                 3,
                 activation='relu',
                 padding='same',
                 kernel_initializer='he_normal')(ublock9)
    
    conv10 = Conv2D(n_classes, kernel_size=1, padding='same')(conv9)  
    model = tf.keras.Model(inputs=inputs, outputs=conv10, name=f"U-Net")
    return model

# %%
img_height = 96
img_width = 128
num_channels = 3

unet_model = build_unet_model((img_height, img_width, num_channels))

# %%
# O modelo mais recente pode ser baixado no kaggle no notebook -> output de criação do modelo
# https://www.kaggle.com/code/marciodelrei/aerial-semantic-segmentation-puc-rio-bi-master-tcc?kernelSessionId=134697143
unet_model.load_weights(r"modelos\20230613141845_bestModelWeigths.h5")
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 96, 128, 3)  0           []
#                                 ]
#
#  conv2d_20 (Conv2D)             (None, 96, 128, 32)  896         ['input_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 96, 128, 32)  9248        ['conv2d_20[0][0]']
#
#  dropout_5 (Dropout)            (None, 96, 128, 32)  0           ['conv2d_21[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 48, 64, 32)  0           ['dropout_5[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 48, 64, 64)   18496       ['max_pooling2d_4[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 48, 64, 64)   36928       ['conv2d_22[0][0]']
#
#  dropout_6 (Dropout)            (None, 48, 64, 64)   0           ['conv2d_23[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 24, 32, 64)  0           ['dropout_6[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 24, 32, 128)  73856       ['max_pooling2d_5[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 24, 32, 128)  147584      ['conv2d_24[0][0]']
#
#  dropout_7 (Dropout)            (None, 24, 32, 128)  0           ['conv2d_25[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 16, 128)  0          ['dropout_7[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 16, 256)  295168      ['max_pooling2d_6[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 12, 16, 256)  590080      ['conv2d_26[0][0]']
#
#  dropout_8 (Dropout)            (None, 12, 16, 256)  0           ['conv2d_27[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 6, 8, 256)   0           ['dropout_8[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 6, 8, 512)    1180160     ['max_pooling2d_7[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 6, 8, 512)    2359808     ['conv2d_28[0][0]']
#
#  dropout_9 (Dropout)            (None, 6, 8, 512)    0           ['conv2d_29[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 12, 16, 256)  1179904    ['dropout_9[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 12, 16, 512)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 12, 16, 256)  1179904     ['concatenate_4[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 12, 16, 256)  590080      ['conv2d_30[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 24, 32, 128)  295040     ['conv2d_31[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 24, 32, 256)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'dropout_7[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 24, 32, 128)  295040      ['concatenate_5[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 24, 32, 128)  147584      ['conv2d_32[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 48, 64, 64)  73792       ['conv2d_33[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 48, 64, 128)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'dropout_6[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 48, 64, 64)   73792       ['concatenate_6[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 48, 64, 64)   36928       ['conv2d_34[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 96, 128, 32)  18464      ['conv2d_35[0][0]']
#  spose)
#
#  concatenate_7 (Concatenate)    (None, 96, 128, 64)  0           ['conv2d_transpose_7[0][0]',
#                                                                   'dropout_5[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 96, 128, 32)  18464       ['concatenate_7[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 96, 128, 32)  9248        ['conv2d_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 96, 128, 32)  9248        ['conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 96, 128, 23)  759         ['conv2d_38[0][0]']
#
# ==================================================================================================
# Total params: 8,640,471
# Trainable params: 8,640,471
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
images = glob(f"{images_path}/*")
image = images[1]
print(image)
# Out:
# fotos\DJI_0091.JPG

# %%
images = glob(f"{images_path}/*")
entra = False
total_colors = []
cont_mask = 0
for idx, image in enumerate(images):
    # if cont_mask > 10:
    #     break
    
    # if idx == 226 :
    print(f"Nome imagem: {image}")
    base_name = os.path.basename(image)
    ext_name = base_name.split(".")[1]
    
    input_image = image
    image_original = process_path(input_image)
    input_image_preprocessed = preprocess_image(image_original)
    
    output_mask = inference(unet_model, input_image_preprocessed)
    # print(f"input_image_preprocessed.shape: {input_image_preprocessed.shape} | output_mask.shape: {output_mask.shape}")
    mask_predicted = create_mask(output_mask)
    # print(f"output_mask.shape: {output_mask.shape} | mask_predicted.shape: {mask_predicted.shape}")
    # display([input_image_preprocessed, mask_predicted])
    
    numpy_array = mask_predicted.numpy()
    # print(f"mask_predicted.shape: {mask_predicted.shape} | numpy_array.shape: {numpy_array.shape}")
    # display([input_image_preprocessed, numpy_array])

    normalized_array = (numpy_array - np.min(numpy_array)) / (np.max(numpy_array) - np.min(numpy_array)) * 255
    # print(f"numpy_array.shape: {numpy_array.shape} | normalized_array.shape: {normalized_array.shape}")
    # display([input_image_preprocessed, normalized_array])

    mask_normalized = normalized_array.astype(np.uint8)
    # print(f"normalized_array.shape: {normalized_array.shape} | mask_normalized.shape: {mask_normalized.shape}")
    # display([input_image_preprocessed, mask_normalized])

    mask_array = np.reshape(mask_normalized, (96, 128))
    # print(f"mask_normalized.shape: {mask_normalized.shape} | mask_array.shape: {mask_array.shape}")
    # display([image_original, mask_array])

    mask_data = Image.fromarray(mask_array)
    mask_data_resized = mask_data.resize((4000, 3000), resample=Image.Resampling.BOX)
    # print(f"len(mask_data.getcolors(): {len(mask_data.getcolors())}")
    # print(f"mask_array.shape: {mask_array.shape} | mask_data.size: {mask_data.size} | mask_data.getcolors: {mask_data.getcolors()}")
    mask_filename = os.path.join(mask_inference_path, f"{base_name}_mask_original.{ext_name}")
    mask_data_resized.save(mask_filename)
    
    mask_data_final = convert_maskgray_to_bw(mask_data)
    if save_image_crivo(mask_data_final, 0.5):
        mask_data_final_resized = mask_data_final.resize((4000, 3000), resample=Image.Resampling.BOX)
        mask_filename = os.path.join(mask_inference_resized_path, f"{base_name}_mask.{ext_name}")
        mask_data_final_resized.save(mask_filename)
        cont_mask += 1
    

    # mask_data_cores = mask_data.getcolors()
    # for tupla in mask_data_cores:
    #     total_colors.append(tupla[1])
        


       
    # break
# Out:
# Nome imagem: fotos\DJI_0090.JPG
# 1/1 [==============================] - 0s 144ms/step
# Mask pixel count: 9 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.0732421875%
# Nome imagem: fotos\DJI_0091.JPG
# 1/1 [==============================] - 0s 139ms/step
# Mask pixel count: 108 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.87890625%
# Nome imagem: fotos\DJI_0092.JPG
# 1/1 [==============================] - 0s 141ms/step
# Mask pixel count: 119 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9684244791666666%
# Nome imagem: fotos\DJI_0093.JPG
# 1/1 [==============================] - 0s 172ms/step
# Mask pixel count: 162 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.318359375%
# Nome imagem: fotos\DJI_0094.JPG
# 1/1 [==============================] - 0s 180ms/step
# Mask pixel count: 81 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6591796875%
# Nome imagem: fotos\DJI_0095.JPG
# 1/1 [==============================] - 0s 138ms/step
# Mask pixel count: 36 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.29296875%
# Nome imagem: fotos\DJI_0096.JPG
# 1/1 [==============================] - 0s 146ms/step
# Mask pixel count: 63 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5126953125%
# Nome imagem: fotos\DJI_0097.JPG
# 1/1 [==============================] - 0s 156ms/step
# Mask pixel count: 57 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.4638671875%
# Nome imagem: fotos\DJI_0098.JPG
# 1/1 [==============================] - 0s 135ms/step
# Mask pixel count: 94 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7649739583333333%
# Nome imagem: fotos\DJI_0099.JPG
# 1/1 [==============================] - 0s 136ms/step
# Mask pixel count: 122 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9928385416666666%
# Nome imagem: fotos\DJI_0100.JPG
# 1/1 [==============================] - 0s 132ms/step
# Mask pixel count: 75 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6103515625%
# Nome imagem: fotos\DJI_0101.JPG
# 1/1 [==============================] - 0s 142ms/step
# Mask pixel count: 100 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8138020833333334%
# Nome imagem: fotos\DJI_0102.JPG
# 1/1 [==============================] - 0s 150ms/step
# Mask pixel count: 109 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8870442708333334%
# Nome imagem: fotos\DJI_0103.JPG
# 1/1 [==============================] - 0s 151ms/step
# Mask pixel count: 101 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8219401041666666%
# Nome imagem: fotos\DJI_0104.JPG
# 1/1 [==============================] - 0s 155ms/step
# Mask pixel count: 89 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7242838541666667%
# Nome imagem: fotos\DJI_0105.JPG
# 1/1 [==============================] - 0s 146ms/step
# Mask pixel count: 94 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7649739583333333%
# Nome imagem: fotos\DJI_0106.JPG
# 1/1 [==============================] - 0s 138ms/step
# Mask pixel count: 66 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.537109375%
# Nome imagem: fotos\DJI_0107.JPG
# 1/1 [==============================] - 0s 143ms/step
# Mask pixel count: 83 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6754557291666667%
# Nome imagem: fotos\DJI_0108.JPG
# 1/1 [==============================] - 0s 139ms/step
# Mask pixel count: 114 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.927734375%
# Nome imagem: fotos\DJI_0109.JPG
# 1/1 [==============================] - 0s 155ms/step
# Mask pixel count: 91 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7405598958333333%
# Nome imagem: fotos\DJI_0110.JPG
# 1/1 [==============================] - 0s 204ms/step
# Mask pixel count: 182 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.4811197916666665%
# Nome imagem: fotos\DJI_0111.JPG
# 1/1 [==============================] - 0s 253ms/step
# Mask pixel count: 123 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0009765625%
# Nome imagem: fotos\DJI_0112.JPG
# 1/1 [==============================] - 0s 280ms/step
# Mask pixel count: 41 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.33365885416666663%
# Nome imagem: fotos\DJI_0113.JPG
# 1/1 [==============================] - 0s 278ms/step
# Mask pixel count: 87 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7080078125%
# Nome imagem: fotos\DJI_0114.JPG
# 1/1 [==============================] - 0s 340ms/step
# Mask pixel count: 80 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6510416666666667%
# Nome imagem: fotos\DJI_0115.JPG
# 1/1 [==============================] - 0s 274ms/step
# Mask pixel count: 88 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7161458333333333%
# Nome imagem: fotos\DJI_0116.JPG
# 1/1 [==============================] - 0s 356ms/step
# Mask pixel count: 122 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9928385416666666%
# Nome imagem: fotos\DJI_0117.JPG
# 1/1 [==============================] - 0s 231ms/step
# Mask pixel count: 181 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.4729817708333335%
# Nome imagem: fotos\DJI_0118.JPG
# 1/1 [==============================] - 0s 278ms/step
# Mask pixel count: 167 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3590494791666665%
# Nome imagem: fotos\DJI_0119.JPG
# 1/1 [==============================] - 0s 252ms/step
# Mask pixel count: 164 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3346354166666665%
# Nome imagem: fotos\DJI_0120.JPG
# 1/1 [==============================] - 0s 264ms/step
# Mask pixel count: 138 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.123046875%
# Nome imagem: fotos\DJI_0121.JPG
# 1/1 [==============================] - 0s 242ms/step
# Mask pixel count: 70 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5696614583333333%
# Nome imagem: fotos\DJI_0122.JPG
# 1/1 [==============================] - 0s 254ms/step
# Mask pixel count: 137 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.1149088541666665%
# Nome imagem: fotos\DJI_0123.JPG
# 1/1 [==============================] - 0s 224ms/step
# Mask pixel count: 71 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5777994791666667%
# Nome imagem: fotos\DJI_0124.JPG
# 1/1 [==============================] - 0s 224ms/step
# Mask pixel count: 91 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7405598958333333%
# Nome imagem: fotos\DJI_0125.JPG
# 1/1 [==============================] - 0s 268ms/step
# Mask pixel count: 76 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6184895833333333%
# Nome imagem: fotos\DJI_0126.JPG
# 1/1 [==============================] - 0s 273ms/step
# Mask pixel count: 97 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7893880208333334%
# Nome imagem: fotos\DJI_0127.JPG
# 1/1 [==============================] - 0s 217ms/step
# Mask pixel count: 163 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3264973958333335%
# Nome imagem: fotos\DJI_0128.JPG
# 1/1 [==============================] - 0s 287ms/step
# Mask pixel count: 141 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.1474609375%
# Nome imagem: fotos\DJI_0129.JPG
# 1/1 [==============================] - 0s 247ms/step
# Mask pixel count: 128 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0416666666666665%
# Nome imagem: fotos\DJI_0130.JPG
# 1/1 [==============================] - 0s 327ms/step
# Mask pixel count: 110 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8951822916666666%
# Nome imagem: fotos\DJI_0131.JPG
# 1/1 [==============================] - 0s 241ms/step
# Mask pixel count: 79 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6429036458333333%
# Nome imagem: fotos\DJI_0132.JPG
# 1/1 [==============================] - 0s 329ms/step
# Mask pixel count: 58 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.4720052083333333%
# Nome imagem: fotos\DJI_0133.JPG
# 1/1 [==============================] - 0s 250ms/step
# Mask pixel count: 66 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.537109375%
# Nome imagem: fotos\DJI_0134.JPG
# 1/1 [==============================] - 0s 266ms/step
# Mask pixel count: 51 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.4150390625%
# Nome imagem: fotos\DJI_0135.JPG
# 1/1 [==============================] - 0s 202ms/step
# Mask pixel count: 65 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5289713541666667%
# Nome imagem: fotos\DJI_0136.JPG
# 1/1 [==============================] - 0s 296ms/step
# Mask pixel count: 51 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.4150390625%
# Nome imagem: fotos\DJI_0137.JPG
# 1/1 [==============================] - 0s 274ms/step
# Mask pixel count: 104 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8463541666666666%
# Nome imagem: fotos\DJI_0138.JPG
# 1/1 [==============================] - 0s 258ms/step
# Mask pixel count: 167 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3590494791666665%
# Nome imagem: fotos\DJI_0139.JPG
# 1/1 [==============================] - 0s 215ms/step
# Mask pixel count: 127 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0335286458333335%
# Nome imagem: fotos\DJI_0140.JPG
# 1/1 [==============================] - 0s 226ms/step
# Mask pixel count: 170 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3834635416666665%
# Nome imagem: fotos\DJI_0141.JPG
# 1/1 [==============================] - 0s 307ms/step
# Mask pixel count: 109 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8870442708333334%
# Nome imagem: fotos\DJI_0142.JPG
# 1/1 [==============================] - 0s 240ms/step
# Mask pixel count: 131 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0660807291666665%
# Nome imagem: fotos\DJI_0143.JPG
# 1/1 [==============================] - 0s 245ms/step
# Mask pixel count: 113 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9195963541666666%
# Nome imagem: fotos\DJI_0144.JPG
# 1/1 [==============================] - 0s 371ms/step
# Mask pixel count: 124 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0091145833333335%
# Nome imagem: fotos\DJI_0145.JPG
# 1/1 [==============================] - 0s 268ms/step
# Mask pixel count: 112 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9114583333333334%
# Nome imagem: fotos\DJI_0146.JPG
# 1/1 [==============================] - 0s 223ms/step
# Mask pixel count: 129 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0498046875%
# Nome imagem: fotos\DJI_0147.JPG
# 1/1 [==============================] - 0s 235ms/step
# Mask pixel count: 163 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3264973958333335%
# Nome imagem: fotos\DJI_0148.JPG
# 1/1 [==============================] - 0s 262ms/step
# Mask pixel count: 144 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.171875%
# Nome imagem: fotos\DJI_0149.JPG
# 1/1 [==============================] - 0s 234ms/step
# Mask pixel count: 165 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3427734375%
# Nome imagem: fotos\DJI_0150.JPG
# 1/1 [==============================] - 0s 288ms/step
# Mask pixel count: 154 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.2532552083333335%
# Nome imagem: fotos\DJI_0151.JPG
# 1/1 [==============================] - 0s 275ms/step
# Mask pixel count: 118 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9602864583333334%
# Nome imagem: fotos\DJI_0152.JPG
# 1/1 [==============================] - 0s 245ms/step
# Mask pixel count: 174 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.416015625%
# Nome imagem: fotos\DJI_0153.JPG
# 1/1 [==============================] - 0s 225ms/step
# Mask pixel count: 184 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.4973958333333335%
# Nome imagem: fotos\DJI_0154.JPG
# 1/1 [==============================] - 0s 261ms/step
# Mask pixel count: 38 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.30924479166666663%
# Nome imagem: fotos\DJI_0155.JPG
# 1/1 [==============================] - 0s 241ms/step
# Mask pixel count: 53 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.4313151041666667%
# Nome imagem: fotos\DJI_0156.JPG
# 1/1 [==============================] - 0s 231ms/step
# Mask pixel count: 48 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.390625%
# Nome imagem: fotos\DJI_0157.JPG
# 1/1 [==============================] - 0s 238ms/step
# Mask pixel count: 53 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.4313151041666667%
# Nome imagem: fotos\DJI_0158.JPG
# 1/1 [==============================] - 0s 207ms/step
# Mask pixel count: 72 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5859375%
# Nome imagem: fotos\DJI_0159.JPG
# 1/1 [==============================] - 0s 213ms/step
# Mask pixel count: 129 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0498046875%
# Nome imagem: fotos\DJI_0160.JPG
# 1/1 [==============================] - 0s 241ms/step
# Mask pixel count: 126 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.025390625%
# Nome imagem: fotos\DJI_0161.JPG
# 1/1 [==============================] - 0s 297ms/step
# Mask pixel count: 101 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8219401041666666%
# Nome imagem: fotos\DJI_0162.JPG
# 1/1 [==============================] - 0s 261ms/step
# Mask pixel count: 98 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7975260416666666%
# Nome imagem: fotos\DJI_0163.JPG
# 1/1 [==============================] - 0s 225ms/step
# Mask pixel count: 118 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9602864583333334%
# Nome imagem: fotos\DJI_0164.JPG
# 1/1 [==============================] - 0s 262ms/step
# Mask pixel count: 181 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.4729817708333335%
# Nome imagem: fotos\DJI_0165.JPG
# 1/1 [==============================] - 0s 204ms/step
# Mask pixel count: 236 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9205729166666667%
# Nome imagem: fotos\DJI_0166.JPG
# 1/1 [==============================] - 0s 209ms/step
# Mask pixel count: 213 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.7333984375%
# Nome imagem: fotos\DJI_0167.JPG
# 1/1 [==============================] - 0s 277ms/step
# Mask pixel count: 168 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3671875%
# Nome imagem: fotos\DJI_0168.JPG
# 1/1 [==============================] - 0s 215ms/step
# Mask pixel count: 137 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.1149088541666665%
# Nome imagem: fotos\DJI_0169.JPG
# 1/1 [==============================] - 0s 275ms/step
# Mask pixel count: 107 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8707682291666666%
# Nome imagem: fotos\DJI_0170.JPG
# 1/1 [==============================] - 0s 247ms/step
# Mask pixel count: 96 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.78125%
# Nome imagem: fotos\DJI_0171.JPG
# 1/1 [==============================] - 0s 332ms/step
# Mask pixel count: 54 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.439453125%
# Nome imagem: fotos\DJI_0172.JPG
# 1/1 [==============================] - 0s 233ms/step
# Mask pixel count: 83 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6754557291666667%
# Nome imagem: fotos\DJI_0173.JPG
# 1/1 [==============================] - 0s 327ms/step
# Mask pixel count: 174 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.416015625%
# Nome imagem: fotos\DJI_0174.JPG
# 1/1 [==============================] - 0s 225ms/step
# Mask pixel count: 127 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0335286458333335%
# Nome imagem: fotos\DJI_0175.JPG
# 1/1 [==============================] - 0s 250ms/step
# Mask pixel count: 126 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.025390625%
# Nome imagem: fotos\DJI_0176.JPG
# 1/1 [==============================] - 0s 290ms/step
# Mask pixel count: 166 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3509114583333335%
# Nome imagem: fotos\DJI_0177.JPG
# 1/1 [==============================] - 0s 262ms/step
# Mask pixel count: 192 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.5625%
# Nome imagem: fotos\DJI_0178.JPG
# 1/1 [==============================] - 0s 288ms/step
# Mask pixel count: 196 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.5950520833333333%
# Nome imagem: fotos\DJI_0179.JPG
# 1/1 [==============================] - 0s 323ms/step
# Mask pixel count: 232 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.8880208333333333%
# Nome imagem: fotos\DJI_0180.JPG
# 1/1 [==============================] - 0s 230ms/step
# Mask pixel count: 65 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5289713541666667%
# Nome imagem: fotos\DJI_0181.JPG
# 1/1 [==============================] - 0s 221ms/step
# Mask pixel count: 47 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.38248697916666663%
# Nome imagem: fotos\DJI_0182.JPG
# 1/1 [==============================] - 0s 239ms/step
# Mask pixel count: 12 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.09765625%
# Nome imagem: fotos\DJI_0183.JPG
# 1/1 [==============================] - 0s 244ms/step
# Mask pixel count: 37 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.30110677083333337%
# Nome imagem: fotos\DJI_0184.JPG
# 1/1 [==============================] - 0s 272ms/step
# Mask pixel count: 47 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.38248697916666663%
# Nome imagem: fotos\DJI_0185.JPG
# 1/1 [==============================] - 0s 235ms/step
# Mask pixel count: 41 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.33365885416666663%
# Nome imagem: fotos\DJI_0186.JPG
# 1/1 [==============================] - 0s 262ms/step
# Mask pixel count: 90 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.732421875%
# Nome imagem: fotos\DJI_0187.JPG
# 1/1 [==============================] - 0s 288ms/step
# Mask pixel count: 84 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.68359375%
# Nome imagem: fotos\DJI_0188.JPG
# 1/1 [==============================] - 0s 323ms/step
# Mask pixel count: 132 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.07421875%
# Nome imagem: fotos\DJI_0189.JPG
# 1/1 [==============================] - 0s 245ms/step
# Mask pixel count: 193 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.5706380208333333%
# Nome imagem: fotos\DJI_0190.JPG
# 1/1 [==============================] - 0s 212ms/step
# Mask pixel count: 150 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.220703125%
# Nome imagem: fotos\DJI_0191.JPG
# 1/1 [==============================] - 0s 253ms/step
# Mask pixel count: 235 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9124348958333333%
# Nome imagem: fotos\DJI_0192.JPG
# 1/1 [==============================] - 0s 314ms/step
# Mask pixel count: 316 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.571614583333333%
# Nome imagem: fotos\DJI_0193.JPG
# 1/1 [==============================] - 0s 228ms/step
# Mask pixel count: 298 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.425130208333333%
# Nome imagem: fotos\DJI_0194.JPG
# 1/1 [==============================] - 0s 241ms/step
# Mask pixel count: 271 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.205403645833333%
# Nome imagem: fotos\DJI_0195.JPG
# 1/1 [==============================] - 0s 257ms/step
# Mask pixel count: 269 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.189127604166667%
# Nome imagem: fotos\DJI_0196.JPG
# 1/1 [==============================] - 0s 295ms/step
# Mask pixel count: 234 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.904296875%
# Nome imagem: fotos\DJI_0197.JPG
# 1/1 [==============================] - 0s 255ms/step
# Mask pixel count: 233 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.8961588541666667%
# Nome imagem: fotos\DJI_0198.JPG
# 1/1 [==============================] - 0s 284ms/step
# Mask pixel count: 121 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9847005208333334%
# Nome imagem: fotos\DJI_0199.JPG
# 1/1 [==============================] - 0s 232ms/step
# Mask pixel count: 122 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9928385416666666%
# Nome imagem: fotos\DJI_0200.JPG
# 1/1 [==============================] - 0s 270ms/step
# Mask pixel count: 94 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7649739583333333%
# Nome imagem: fotos\DJI_0201.JPG
# 1/1 [==============================] - 0s 277ms/step
# Mask pixel count: 103 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8382161458333334%
# Nome imagem: fotos\DJI_0202.JPG
# 1/1 [==============================] - 0s 229ms/step
# Mask pixel count: 80 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6510416666666667%
# Nome imagem: fotos\DJI_0203.JPG
# 1/1 [==============================] - 0s 287ms/step
# Mask pixel count: 68 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5533854166666667%
# Nome imagem: fotos\DJI_0204.JPG
# 1/1 [==============================] - 0s 217ms/step
# Mask pixel count: 34 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.27669270833333337%
# Nome imagem: fotos\DJI_0205.JPG
# 1/1 [==============================] - 0s 210ms/step
# Mask pixel count: 163 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3264973958333335%
# Nome imagem: fotos\DJI_0206.JPG
# 1/1 [==============================] - 0s 241ms/step
# Mask pixel count: 122 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9928385416666666%
# Nome imagem: fotos\DJI_0207.JPG
# 1/1 [==============================] - 0s 212ms/step
# Mask pixel count: 177 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.4404296875%
# Nome imagem: fotos\DJI_0208.JPG
# 1/1 [==============================] - 0s 339ms/step
# Mask pixel count: 109 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8870442708333334%
# Nome imagem: fotos\DJI_0209.JPG
# 1/1 [==============================] - 0s 227ms/step
# Mask pixel count: 128 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0416666666666665%
# Nome imagem: fotos\DJI_0210.JPG
# 1/1 [==============================] - 0s 325ms/step
# Mask pixel count: 136 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.1067708333333335%
# Nome imagem: fotos\DJI_0211.JPG
# 1/1 [==============================] - 0s 322ms/step
# Mask pixel count: 148 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.2044270833333335%
# Nome imagem: fotos\DJI_0212.JPG
# 1/1 [==============================] - 0s 358ms/step
# Mask pixel count: 90 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.732421875%
# Nome imagem: fotos\DJI_0213.JPG
# 1/1 [==============================] - 0s 200ms/step
# Mask pixel count: 71 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5777994791666667%
# Nome imagem: fotos\DJI_0214.JPG
# 1/1 [==============================] - 0s 262ms/step
# Mask pixel count: 98 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7975260416666666%
# Nome imagem: fotos\DJI_0215.JPG
# 1/1 [==============================] - 0s 291ms/step
# Mask pixel count: 38 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.30924479166666663%
# Nome imagem: fotos\DJI_0216.JPG
# 1/1 [==============================] - 0s 203ms/step
# Mask pixel count: 54 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.439453125%
# Nome imagem: fotos\DJI_0217.JPG
# 1/1 [==============================] - 0s 214ms/step
# Mask pixel count: 69 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5615234375%
# Nome imagem: fotos\DJI_0218.JPG
# 1/1 [==============================] - 0s 239ms/step
# Mask pixel count: 62 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5045572916666667%
# Nome imagem: fotos\DJI_0219.JPG
# 1/1 [==============================] - 0s 225ms/step
# Mask pixel count: 122 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9928385416666666%
# Nome imagem: fotos\DJI_0220.JPG
# 1/1 [==============================] - 0s 343ms/step
# Mask pixel count: 151 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.2288411458333335%
# Nome imagem: fotos\DJI_0221.JPG
# 1/1 [==============================] - 0s 249ms/step
# Mask pixel count: 183 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.4892578125%
# Nome imagem: fotos\DJI_0222.JPG
# 1/1 [==============================] - 0s 254ms/step
# Mask pixel count: 245 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9938151041666667%
# Nome imagem: fotos\DJI_0223.JPG
# 1/1 [==============================] - 0s 295ms/step
# Mask pixel count: 343 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.791341145833333%
# Nome imagem: fotos\DJI_0224.JPG
# 1/1 [==============================] - 0s 293ms/step
# Mask pixel count: 366 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.978515625%
# Nome imagem: fotos\DJI_0225.JPG
# 1/1 [==============================] - 0s 228ms/step
# Mask pixel count: 301 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.449544270833333%
# Nome imagem: fotos\DJI_0226.JPG
# 1/1 [==============================] - 0s 228ms/step
# Mask pixel count: 205 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.6682942708333333%
# Nome imagem: fotos\DJI_0227.JPG
# 1/1 [==============================] - 0s 240ms/step
# Mask pixel count: 243 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9775390625%
# Nome imagem: fotos\DJI_0228.JPG
# 1/1 [==============================] - 0s 258ms/step
# Mask pixel count: 242 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9694010416666667%
# Nome imagem: fotos\DJI_0229.JPG
# 1/1 [==============================] - 0s 361ms/step
# Mask pixel count: 228 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.85546875%
# Nome imagem: fotos\DJI_0230.JPG
# 1/1 [==============================] - 0s 273ms/step
# Mask pixel count: 312 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.5390625%
# Nome imagem: fotos\DJI_0231.JPG
# 1/1 [==============================] - 0s 212ms/step
# Mask pixel count: 238 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9368489583333333%
# Nome imagem: fotos\DJI_0232.JPG
# 1/1 [==============================] - 0s 244ms/step
# Mask pixel count: 226 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.8391927083333333%
# Nome imagem: fotos\DJI_0233.JPG
# 1/1 [==============================] - 0s 255ms/step
# Mask pixel count: 191 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.5543619791666665%
# Nome imagem: fotos\DJI_0234.JPG
# 1/1 [==============================] - 0s 272ms/step
# Mask pixel count: 191 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.5543619791666665%
# Nome imagem: fotos\DJI_0235.JPG
# 1/1 [==============================] - 0s 233ms/step
# Mask pixel count: 183 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.4892578125%
# Nome imagem: fotos\DJI_0236.JPG
# 1/1 [==============================] - 0s 354ms/step
# Mask pixel count: 123 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0009765625%
# Nome imagem: fotos\DJI_0237.JPG
# 1/1 [==============================] - 0s 204ms/step
# Mask pixel count: 165 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3427734375%
# Nome imagem: fotos\DJI_0238.JPG
# 1/1 [==============================] - 0s 275ms/step
# Mask pixel count: 121 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9847005208333334%
# Nome imagem: fotos\DJI_0239.JPG
# 1/1 [==============================] - 0s 244ms/step
# Mask pixel count: 100 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8138020833333334%
# Nome imagem: fotos\DJI_0240.JPG
# 1/1 [==============================] - 0s 205ms/step
# Mask pixel count: 131 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0660807291666665%
# Nome imagem: fotos\DJI_0241.JPG
# 1/1 [==============================] - 0s 236ms/step
# Mask pixel count: 131 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0660807291666665%
# Nome imagem: fotos\DJI_0242.JPG
# 1/1 [==============================] - 0s 346ms/step
# Mask pixel count: 146 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.1881510416666665%
# Nome imagem: fotos\DJI_0243.JPG
# 1/1 [==============================] - 0s 266ms/step
# Mask pixel count: 126 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.025390625%
# Nome imagem: fotos\DJI_0244.JPG
# 1/1 [==============================] - 0s 194ms/step
# Mask pixel count: 129 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0498046875%
# Nome imagem: fotos\DJI_0245.JPG
# 1/1 [==============================] - 0s 267ms/step
# Mask pixel count: 114 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.927734375%
# Nome imagem: fotos\DJI_0246.JPG
# 1/1 [==============================] - 0s 260ms/step
# Mask pixel count: 98 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7975260416666666%
# Nome imagem: fotos\DJI_0247.JPG
# 1/1 [==============================] - 0s 283ms/step
# Mask pixel count: 113 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9195963541666666%
# Nome imagem: fotos\DJI_0248.JPG
# 1/1 [==============================] - 0s 234ms/step
# Mask pixel count: 112 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9114583333333334%
# Nome imagem: fotos\DJI_0249.JPG
# 1/1 [==============================] - 0s 264ms/step
# Mask pixel count: 108 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.87890625%
# Nome imagem: fotos\DJI_0250.JPG
# 1/1 [==============================] - 0s 213ms/step
# Mask pixel count: 89 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7242838541666667%
# Nome imagem: fotos\DJI_0251.JPG
# 1/1 [==============================] - 0s 217ms/step
# Mask pixel count: 118 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.9602864583333334%
# Nome imagem: fotos\DJI_0252.JPG
# 1/1 [==============================] - 0s 276ms/step
# Mask pixel count: 61 | Image pixel total: 12288
# False: crivo=0.5%, calculado:0.4964192708333333%
# Nome imagem: fotos\DJI_0253.JPG
# 1/1 [==============================] - 0s 341ms/step
# Mask pixel count: 103 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8382161458333334%
# Nome imagem: fotos\DJI_0254.JPG
# 1/1 [==============================] - 0s 245ms/step
# Mask pixel count: 89 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.7242838541666667%
# Nome imagem: fotos\DJI_0255.JPG
# 1/1 [==============================] - 0s 299ms/step
# Mask pixel count: 100 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8138020833333334%
# Nome imagem: fotos\DJI_0256.JPG
# 1/1 [==============================] - 0s 287ms/step
# Mask pixel count: 161 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3102213541666665%
# Nome imagem: fotos\DJI_0257.JPG
# 1/1 [==============================] - 0s 233ms/step
# Mask pixel count: 207 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.6845703125%
# Nome imagem: fotos\DJI_0258.JPG
# 1/1 [==============================] - 0s 263ms/step
# Mask pixel count: 245 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9938151041666667%
# Nome imagem: fotos\DJI_0259.JPG
# 1/1 [==============================] - 0s 217ms/step
# Mask pixel count: 339 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.7587890625%
# Nome imagem: fotos\DJI_0260.JPG
# 1/1 [==============================] - 0s 232ms/step
# Mask pixel count: 297 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.4169921875%
# Nome imagem: fotos\DJI_0261.JPG
# 1/1 [==============================] - 0s 214ms/step
# Mask pixel count: 234 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.904296875%
# Nome imagem: fotos\DJI_0262.JPG
# 1/1 [==============================] - 0s 252ms/step
# Mask pixel count: 229 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.8636067708333333%
# Nome imagem: fotos\DJI_0263.JPG
# 1/1 [==============================] - 0s 286ms/step
# Mask pixel count: 316 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.571614583333333%
# Nome imagem: fotos\DJI_0264.JPG
# 1/1 [==============================] - 0s 246ms/step
# Mask pixel count: 244 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9856770833333333%
# Nome imagem: fotos\DJI_0265.JPG
# 1/1 [==============================] - 0s 240ms/step
# Mask pixel count: 172 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3997395833333335%
# Nome imagem: fotos\DJI_0266.JPG
# 1/1 [==============================] - 0s 273ms/step
# Mask pixel count: 321 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.6123046875%
# Nome imagem: fotos\DJI_0267.JPG
# 1/1 [==============================] - 0s 290ms/step
# Mask pixel count: 381 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.1005859375%
# Nome imagem: fotos\DJI_0268.JPG
# 1/1 [==============================] - 0s 207ms/step
# Mask pixel count: 332 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.701822916666667%
# Nome imagem: fotos\DJI_0269.JPG
# 1/1 [==============================] - 0s 222ms/step
# Mask pixel count: 482 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.9225260416666665%
# Nome imagem: fotos\DJI_0270.JPG
# 1/1 [==============================] - 0s 256ms/step
# Mask pixel count: 436 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.5481770833333335%
# Nome imagem: fotos\DJI_0271.JPG
# 1/1 [==============================] - 0s 260ms/step
# Mask pixel count: 541 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.402669270833334%
# Nome imagem: fotos\DJI_0272.JPG
# 1/1 [==============================] - 0s 237ms/step
# Mask pixel count: 499 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.060872395833334%
# Nome imagem: fotos\DJI_0273.JPG
# 1/1 [==============================] - 0s 211ms/step
# Mask pixel count: 522 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.248046875%
# Nome imagem: fotos\DJI_0274.JPG
# 1/1 [==============================] - 0s 203ms/step
# Mask pixel count: 500 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.069010416666666%
# Nome imagem: fotos\DJI_0275.JPG
# 1/1 [==============================] - 0s 225ms/step
# Mask pixel count: 452 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.6783854166666665%
# Nome imagem: fotos\DJI_0276.JPG
# 1/1 [==============================] - 0s 258ms/step
# Mask pixel count: 426 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.466796875%
# Nome imagem: fotos\DJI_0277.JPG
# 1/1 [==============================] - 0s 332ms/step
# Mask pixel count: 381 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.1005859375%
# Nome imagem: fotos\DJI_0278.JPG
# 1/1 [==============================] - 0s 337ms/step
# Mask pixel count: 307 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.498372395833333%
# Nome imagem: fotos\DJI_0279.JPG
# 1/1 [==============================] - 0s 252ms/step
# Mask pixel count: 175 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.4241536458333335%
# Nome imagem: fotos\DJI_0280.JPG
# 1/1 [==============================] - 0s 285ms/step
# Mask pixel count: 130 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0579427083333335%
# Nome imagem: fotos\DJI_0281.JPG
# 1/1 [==============================] - 0s 284ms/step
# Mask pixel count: 137 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.1149088541666665%
# Nome imagem: fotos\DJI_0282.JPG
# 1/1 [==============================] - 0s 254ms/step
# Mask pixel count: 101 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8219401041666666%
# Nome imagem: fotos\DJI_0283.JPG
# 1/1 [==============================] - 0s 224ms/step
# Mask pixel count: 83 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6754557291666667%
# Nome imagem: fotos\DJI_0284.JPG
# 1/1 [==============================] - 0s 219ms/step
# Mask pixel count: 96 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.78125%
# Nome imagem: fotos\DJI_0285.JPG
# 1/1 [==============================] - 0s 330ms/step
# Mask pixel count: 76 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.6184895833333333%
# Nome imagem: fotos\DJI_0286.JPG
# 1/1 [==============================] - 0s 302ms/step
# Mask pixel count: 101 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.8219401041666666%
# Nome imagem: fotos\DJI_0287.JPG
# 1/1 [==============================] - 0s 218ms/step
# Mask pixel count: 235 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9124348958333333%
# Nome imagem: fotos\DJI_0288.JPG
# 1/1 [==============================] - 0s 257ms/step
# Mask pixel count: 243 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9775390625%
# Nome imagem: fotos\DJI_0289.JPG
# 1/1 [==============================] - 0s 250ms/step
# Mask pixel count: 255 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.0751953125%
# Nome imagem: fotos\DJI_0290.JPG
# 1/1 [==============================] - 0s 233ms/step
# Mask pixel count: 239 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9449869791666667%
# Nome imagem: fotos\DJI_0291.JPG
# 1/1 [==============================] - 0s 245ms/step
# Mask pixel count: 266 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.164713541666667%
# Nome imagem: fotos\DJI_0292.JPG
# 1/1 [==============================] - 0s 287ms/step
# Mask pixel count: 302 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.457682291666667%
# Nome imagem: fotos\DJI_0293.JPG
# 1/1 [==============================] - 0s 249ms/step
# Mask pixel count: 378 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.076171875%
# Nome imagem: fotos\DJI_0294.JPG
# 1/1 [==============================] - 0s 200ms/step
# Mask pixel count: 526 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.280598958333334%
# Nome imagem: fotos\DJI_0295.JPG
# 1/1 [==============================] - 0s 367ms/step
# Mask pixel count: 560 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.557291666666666%
# Nome imagem: fotos\DJI_0296.JPG
# 1/1 [==============================] - 0s 389ms/step
# Mask pixel count: 670 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.452473958333334%
# Nome imagem: fotos\DJI_0297.JPG
# 1/1 [==============================] - 0s 257ms/step
# Mask pixel count: 783 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.3720703125%
# Nome imagem: fotos\DJI_0298.JPG
# 1/1 [==============================] - 0s 277ms/step
# Mask pixel count: 676 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.501302083333334%
# Nome imagem: fotos\DJI_0299.JPG
# 1/1 [==============================] - 0s 278ms/step
# Mask pixel count: 586 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.768880208333334%
# Nome imagem: fotos\DJI_0300.JPG
# 1/1 [==============================] - 0s 262ms/step
# Mask pixel count: 567 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.6142578125%
# Nome imagem: fotos\DJI_0301.JPG
# 1/1 [==============================] - 0s 226ms/step
# Mask pixel count: 560 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.557291666666666%
# Nome imagem: fotos\DJI_0302.JPG
# 1/1 [==============================] - 0s 207ms/step
# Mask pixel count: 676 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.501302083333334%
# Nome imagem: fotos\DJI_0303.JPG
# 1/1 [==============================] - 0s 280ms/step
# Mask pixel count: 612 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.98046875%
# Nome imagem: fotos\DJI_0304.JPG
# 1/1 [==============================] - 0s 278ms/step
# Mask pixel count: 479 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.8981119791666665%
# Nome imagem: fotos\DJI_0305.JPG
# 1/1 [==============================] - 0s 336ms/step
# Mask pixel count: 463 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.7679036458333335%
# Nome imagem: fotos\DJI_0306.JPG
# 1/1 [==============================] - 0s 238ms/step
# Mask pixel count: 593 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.825846354166666%
# Nome imagem: fotos\DJI_0307.JPG
# 1/1 [==============================] - 0s 259ms/step
# Mask pixel count: 699 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.6884765625%
# Nome imagem: fotos\DJI_0308.JPG
# 1/1 [==============================] - 0s 310ms/step
# Mask pixel count: 570 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.638671875%
# Nome imagem: fotos\DJI_0309.JPG
# 1/1 [==============================] - 0s 275ms/step
# Mask pixel count: 618 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.029296875%
# Nome imagem: fotos\DJI_0310.JPG
# 1/1 [==============================] - 0s 290ms/step
# Mask pixel count: 573 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.6630859375%
# Nome imagem: fotos\DJI_0311.JPG
# 1/1 [==============================] - 0s 230ms/step
# Mask pixel count: 714 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.810546875%
# Nome imagem: fotos\DJI_0312.JPG
# 1/1 [==============================] - 0s 273ms/step
# Mask pixel count: 712 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.794270833333334%
# Nome imagem: fotos\DJI_0313.JPG
# 1/1 [==============================] - 0s 248ms/step
# Mask pixel count: 788 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.412760416666667%
# Nome imagem: fotos\DJI_0314.JPG
# 1/1 [==============================] - 0s 216ms/step
# Mask pixel count: 863 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.023111979166667%
# Nome imagem: fotos\DJI_0315.JPG
# 1/1 [==============================] - 0s 302ms/step
# Mask pixel count: 798 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.494140625%
# Nome imagem: fotos\DJI_0316.JPG
# 1/1 [==============================] - 0s 220ms/step
# Mask pixel count: 816 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.640625%
# Nome imagem: fotos\DJI_0317.JPG
# 1/1 [==============================] - 0s 221ms/step
# Mask pixel count: 698 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.680338541666666%
# Nome imagem: fotos\DJI_0318.JPG
# 1/1 [==============================] - 0s 287ms/step
# Mask pixel count: 600 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.8828125%
# Nome imagem: fotos\DJI_0319.JPG
# 1/1 [==============================] - 0s 207ms/step
# Mask pixel count: 521 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.239908854166666%
# Nome imagem: fotos\DJI_0320.JPG
# 1/1 [==============================] - 0s 229ms/step
# Mask pixel count: 355 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.888997395833333%
# Nome imagem: fotos\DJI_0321.JPG
# 1/1 [==============================] - 0s 201ms/step
# Mask pixel count: 299 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.433268229166667%
# Nome imagem: fotos\DJI_0322.JPG
# 1/1 [==============================] - 0s 253ms/step
# Mask pixel count: 236 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9205729166666667%
# Nome imagem: fotos\DJI_0323.JPG
# 1/1 [==============================] - 0s 281ms/step
# Mask pixel count: 256 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.083333333333333%
# Nome imagem: fotos\DJI_0324.JPG
# 1/1 [==============================] - 0s 251ms/step
# Mask pixel count: 186 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.513671875%
# Nome imagem: fotos\DJI_0325.JPG
# 1/1 [==============================] - 0s 238ms/step
# Mask pixel count: 102 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.830078125%
# Nome imagem: fotos\DJI_0326.JPG
# 1/1 [==============================] - 0s 256ms/step
# Mask pixel count: 67 | Image pixel total: 12288
# True: crivo=0.5%, calculado:0.5452473958333333%
# Nome imagem: fotos\DJI_0327.JPG
# 1/1 [==============================] - 0s 320ms/step
# Mask pixel count: 167 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.3590494791666665%
# Nome imagem: fotos\DJI_0328.JPG
# 1/1 [==============================] - 0s 270ms/step
# Mask pixel count: 222 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.806640625%
# Nome imagem: fotos\DJI_0329.JPG
# 1/1 [==============================] - 0s 293ms/step
# Mask pixel count: 316 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.571614583333333%
# Nome imagem: fotos\DJI_0330.JPG
# 1/1 [==============================] - 0s 193ms/step
# Mask pixel count: 313 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.547200520833333%
# Nome imagem: fotos\DJI_0331.JPG
# 1/1 [==============================] - 0s 218ms/step
# Mask pixel count: 305 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.482096354166667%
# Nome imagem: fotos\DJI_0332.JPG
# 1/1 [==============================] - 0s 274ms/step
# Mask pixel count: 419 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.4098307291666665%
# Nome imagem: fotos\DJI_0333.JPG
# 1/1 [==============================] - 0s 244ms/step
# Mask pixel count: 515 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.191080729166666%
# Nome imagem: fotos\DJI_0334.JPG
# 1/1 [==============================] - 0s 356ms/step
# Mask pixel count: 558 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.541015625%
# Nome imagem: fotos\DJI_0335.JPG
# 1/1 [==============================] - 0s 208ms/step
# Mask pixel count: 687 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.5908203125%
# Nome imagem: fotos\DJI_0336.JPG
# 1/1 [==============================] - 0s 214ms/step
# Mask pixel count: 835 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.795247395833333%
# Nome imagem: fotos\DJI_0337.JPG
# 1/1 [==============================] - 0s 235ms/step
# Mask pixel count: 837 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.8115234375%
# Nome imagem: fotos\DJI_0338.JPG
# 1/1 [==============================] - 0s 246ms/step
# Mask pixel count: 890 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.242838541666667%
# Nome imagem: fotos\DJI_0339.JPG
# 1/1 [==============================] - 0s 278ms/step
# Mask pixel count: 758 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.168619791666666%
# Nome imagem: fotos\DJI_0340.JPG
# 1/1 [==============================] - 0s 208ms/step
# Mask pixel count: 832 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.770833333333333%
# Nome imagem: fotos\DJI_0341.JPG
# 1/1 [==============================] - 0s 287ms/step
# Mask pixel count: 821 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.681315104166667%
# Nome imagem: fotos\DJI_0342.JPG
# 1/1 [==============================] - 0s 268ms/step
# Mask pixel count: 689 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.607096354166666%
# Nome imagem: fotos\DJI_0343.JPG
# 1/1 [==============================] - 0s 202ms/step
# Mask pixel count: 648 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.2734375%
# Nome imagem: fotos\DJI_0344.JPG
# 1/1 [==============================] - 0s 327ms/step
# Mask pixel count: 702 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.712890625%
# Nome imagem: fotos\DJI_0345.JPG
# 1/1 [==============================] - 0s 306ms/step
# Mask pixel count: 824 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.705729166666667%
# Nome imagem: fotos\DJI_0346.JPG
# 1/1 [==============================] - 0s 198ms/step
# Mask pixel count: 809 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.583658854166667%
# Nome imagem: fotos\DJI_0347.JPG
# 1/1 [==============================] - 0s 246ms/step
# Mask pixel count: 657 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.3466796875%
# Nome imagem: fotos\DJI_0348.JPG
# 1/1 [==============================] - 0s 220ms/step
# Mask pixel count: 492 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.00390625%
# Nome imagem: fotos\DJI_0349.JPG
# 1/1 [==============================] - 0s 240ms/step
# Mask pixel count: 377 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.068033854166667%
# Nome imagem: fotos\DJI_0350.JPG
# 1/1 [==============================] - 0s 267ms/step
# Mask pixel count: 394 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.2063802083333335%
# Nome imagem: fotos\DJI_0351.JPG
# 1/1 [==============================] - 0s 295ms/step
# Mask pixel count: 487 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.9632161458333335%
# Nome imagem: fotos\DJI_0352.JPG
# 1/1 [==============================] - 0s 328ms/step
# Mask pixel count: 532 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.329427083333334%
# Nome imagem: fotos\DJI_0353.JPG
# 1/1 [==============================] - 0s 325ms/step
# Mask pixel count: 498 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.052734375%
# Nome imagem: fotos\DJI_0354.JPG
# 1/1 [==============================] - 0s 333ms/step
# Mask pixel count: 566 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.606119791666666%
# Nome imagem: fotos\DJI_0355.JPG
# 1/1 [==============================] - 0s 324ms/step
# Mask pixel count: 636 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.17578125%
# Nome imagem: fotos\DJI_0356.JPG
# 1/1 [==============================] - 0s 238ms/step
# Mask pixel count: 626 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.094401041666666%
# Nome imagem: fotos\DJI_0357.JPG
# 1/1 [==============================] - 0s 275ms/step
# ...
# Nome imagem: fotos\DJI_0359.JPG
# 1/1 [==============================] - 0s 250ms/step
# Mask pixel count: 784 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.380208333333333%
# Nome imagem: fotos\DJI_0360.JPG
# 1/1 [==============================] - 0s 238ms/step
# Mask pixel count: 786 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.396484375%
# Nome imagem: fotos\DJI_0361.JPG
# 1/1 [==============================] - 0s 278ms/step
# Mask pixel count: 733 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.965169270833334%
# Nome imagem: fotos\DJI_0362.JPG
# 1/1 [==============================] - 0s 276ms/step
# Mask pixel count: 759 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.1767578125%
# Nome imagem: fotos\DJI_0363.JPG
# 1/1 [==============================] - 0s 234ms/step
# Mask pixel count: 695 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.655924479166666%
# Nome imagem: fotos\DJI_0364.JPG
# 1/1 [==============================] - 0s 409ms/step
# Mask pixel count: 625 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.086263020833334%
# Nome imagem: fotos\DJI_0365.JPG
# 1/1 [==============================] - 0s 325ms/step
# Mask pixel count: 444 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.61328125%
# Nome imagem: fotos\DJI_0366.JPG
# 1/1 [==============================] - 0s 221ms/step
# Mask pixel count: 408 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.3203125%
# Nome imagem: fotos\DJI_0367.JPG
# 1/1 [==============================] - 0s 245ms/step
# Mask pixel count: 390 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.173828125%
# Nome imagem: fotos\DJI_0368.JPG
# 1/1 [==============================] - 0s 227ms/step
# Mask pixel count: 330 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.685546875%
# Nome imagem: fotos\DJI_0369.JPG
# 1/1 [==============================] - 0s 210ms/step
# Mask pixel count: 251 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.042643229166667%
# Nome imagem: fotos\DJI_0370.JPG
# 1/1 [==============================] - 0s 267ms/step
# Mask pixel count: 197 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.6031901041666667%
# Nome imagem: fotos\DJI_0371.JPG
# 1/1 [==============================] - 0s 252ms/step
# Mask pixel count: 131 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0660807291666665%
# Nome imagem: fotos\DJI_0372.JPG
# 1/1 [==============================] - 0s 277ms/step
# Mask pixel count: 130 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.0579427083333335%
# Nome imagem: fotos\DJI_0373.JPG
# 1/1 [==============================] - 0s 212ms/step
# Mask pixel count: 224 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.8229166666666667%
# Nome imagem: fotos\DJI_0374.JPG
# 1/1 [==============================] - 0s 275ms/step
# Mask pixel count: 365 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.970377604166667%
# Nome imagem: fotos\DJI_0375.JPG
# 1/1 [==============================] - 0s 211ms/step
# Mask pixel count: 441 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.5888671875%
# Nome imagem: fotos\DJI_0376.JPG
# 1/1 [==============================] - 0s 223ms/step
# Mask pixel count: 339 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.7587890625%
# Nome imagem: fotos\DJI_0377.JPG
# 1/1 [==============================] - 0s 220ms/step
# Mask pixel count: 433 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.5237630208333335%
# Nome imagem: fotos\DJI_0378.JPG
# 1/1 [==============================] - 0s 378ms/step
# Mask pixel count: 428 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.4830729166666665%
# Nome imagem: fotos\DJI_0379.JPG
# 1/1 [==============================] - 0s 209ms/step
# Mask pixel count: 554 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.508463541666666%
# Nome imagem: fotos\DJI_0380.JPG
# 1/1 [==============================] - 0s 258ms/step
# Mask pixel count: 610 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.964192708333334%
# Nome imagem: fotos\DJI_0381.JPG
# 1/1 [==============================] - 0s 214ms/step
# Mask pixel count: 682 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.550130208333334%
# Nome imagem: fotos\DJI_0382.JPG
# 1/1 [==============================] - 0s 272ms/step
# Mask pixel count: 796 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.477864583333333%
# Nome imagem: fotos\DJI_0383.JPG
# 1/1 [==============================] - 0s 229ms/step
# Mask pixel count: 893 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.267252604166667%
# Nome imagem: fotos\DJI_0384.JPG
# 1/1 [==============================] - 0s 264ms/step
# Mask pixel count: 873 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.1044921875%
# Nome imagem: fotos\DJI_0385.JPG
# 1/1 [==============================] - 0s 229ms/step
# Mask pixel count: 805 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.551106770833333%
# Nome imagem: fotos\DJI_0386.JPG
# 1/1 [==============================] - 0s 234ms/step
# Mask pixel count: 889 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.234700520833333%
# Nome imagem: fotos\DJI_0387.JPG
# 1/1 [==============================] - 0s 331ms/step
# Mask pixel count: 808 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.575520833333333%
# Nome imagem: fotos\DJI_0388.JPG
# 1/1 [==============================] - 0s 228ms/step
# Mask pixel count: 646 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.257161458333334%
# Nome imagem: fotos\DJI_0389.JPG
# 1/1 [==============================] - 0s 222ms/step
# Mask pixel count: 663 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.3955078125%
# Nome imagem: fotos\DJI_0390.JPG
# 1/1 [==============================] - 0s 233ms/step
# Mask pixel count: 725 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.900065104166666%
# Nome imagem: fotos\DJI_0391.JPG
# 1/1 [==============================] - 0s 245ms/step
# Mask pixel count: 712 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.794270833333334%
# Nome imagem: fotos\DJI_0392.JPG
# 1/1 [==============================] - 0s 275ms/step
# Mask pixel count: 600 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.8828125%
# Nome imagem: fotos\DJI_0393.JPG
# 1/1 [==============================] - 0s 239ms/step
# Mask pixel count: 518 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.215494791666666%
# Nome imagem: fotos\DJI_0394.JPG
# 1/1 [==============================] - 0s 286ms/step
# Mask pixel count: 346 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.815755208333333%
# Nome imagem: fotos\DJI_0395.JPG
# 1/1 [==============================] - 0s 206ms/step
# Mask pixel count: 155 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.2613932291666665%
# Nome imagem: fotos\DJI_0396.JPG
# 1/1 [==============================] - 0s 287ms/step
# Mask pixel count: 206 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.6764322916666667%
# Nome imagem: fotos\DJI_0397.JPG
# 1/1 [==============================] - 0s 252ms/step
# Mask pixel count: 438 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.564453125%
# Nome imagem: fotos\DJI_0398.JPG
# 1/1 [==============================] - 0s 250ms/step
# Mask pixel count: 613 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.988606770833334%
# Nome imagem: fotos\DJI_0399.JPG
# 1/1 [==============================] - 0s 240ms/step
# Mask pixel count: 626 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.094401041666666%
# Nome imagem: fotos\DJI_0400.JPG
# 1/1 [==============================] - 0s 230ms/step
# Mask pixel count: 615 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.0048828125%
# Nome imagem: fotos\DJI_0401.JPG
# 1/1 [==============================] - 0s 226ms/step
# Mask pixel count: 644 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.240885416666666%
# Nome imagem: fotos\DJI_0402.JPG
# 1/1 [==============================] - 0s 286ms/step
# Mask pixel count: 604 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.915364583333334%
# Nome imagem: fotos\DJI_0403.JPG
# 1/1 [==============================] - 0s 258ms/step
# Mask pixel count: 726 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.908203125%
# Nome imagem: fotos\DJI_0404.JPG
# 1/1 [==============================] - 0s 245ms/step
# Mask pixel count: 672 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.46875%
# Nome imagem: fotos\DJI_0405.JPG
# 1/1 [==============================] - 0s 202ms/step
# Mask pixel count: 667 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.428059895833334%
# Nome imagem: fotos\DJI_0406.JPG
# 1/1 [==============================] - 0s 228ms/step
# Mask pixel count: 701 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.704752604166666%
# Nome imagem: fotos\DJI_0407.JPG
# 1/1 [==============================] - 0s 251ms/step
# Mask pixel count: 772 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.282552083333333%
# Nome imagem: fotos\DJI_0408.JPG
# 1/1 [==============================] - 0s 260ms/step
# Mask pixel count: 754 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.136067708333334%
# Nome imagem: fotos\DJI_0409.JPG
# 1/1 [==============================] - 0s 203ms/step
# Mask pixel count: 707 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.753580729166666%
# Nome imagem: fotos\DJI_0410.JPG
# 1/1 [==============================] - 0s 255ms/step
# Mask pixel count: 786 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.396484375%
# Nome imagem: fotos\DJI_0411.JPG
# 1/1 [==============================] - 0s 250ms/step
# Mask pixel count: 731 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.948893229166666%
# Nome imagem: fotos\DJI_0412.JPG
# 1/1 [==============================] - 0s 271ms/step
# Mask pixel count: 708 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.76171875%
# Nome imagem: fotos\DJI_0413.JPG
# 1/1 [==============================] - 0s 195ms/step
# Mask pixel count: 661 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.379231770833334%
# Nome imagem: fotos\DJI_0414.JPG
# 1/1 [==============================] - 0s 221ms/step
# Mask pixel count: 569 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.630533854166666%
# Nome imagem: fotos\DJI_0415.JPG
# 1/1 [==============================] - 0s 238ms/step
# Mask pixel count: 489 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.9794921875%
# Nome imagem: fotos\DJI_0416.JPG
# 1/1 [==============================] - 0s 325ms/step
# Mask pixel count: 387 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.1494140625%
# Nome imagem: fotos\DJI_0417.JPG
# 1/1 [==============================] - 0s 377ms/step
# Mask pixel count: 350 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.848307291666667%
# Nome imagem: fotos\DJI_0418.JPG
# 1/1 [==============================] - 0s 229ms/step
# Mask pixel count: 356 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.897135416666667%
# Nome imagem: fotos\DJI_0419.JPG
# 1/1 [==============================] - 0s 356ms/step
# Mask pixel count: 293 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.384440104166667%
# Nome imagem: fotos\DJI_0420.JPG
# 1/1 [==============================] - 0s 279ms/step
# Mask pixel count: 345 | Image pixel total: 12288
# True: crivo=0.5%, calculado:2.8076171875%
# Nome imagem: fotos\DJI_0421.JPG
# 1/1 [==============================] - 0s 205ms/step
# Mask pixel count: 236 | Image pixel total: 12288
# True: crivo=0.5%, calculado:1.9205729166666667%
# Nome imagem: fotos\DJI_0422.JPG
# 1/1 [==============================] - 0s 282ms/step
# Mask pixel count: 482 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.9225260416666665%
# Nome imagem: fotos\DJI_0423.JPG
# 1/1 [==============================] - 0s 247ms/step
# Mask pixel count: 511 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.158528645833334%
# Nome imagem: fotos\DJI_0424.JPG
# 1/1 [==============================] - 0s 229ms/step
# Mask pixel count: 450 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.662109375%
# Nome imagem: fotos\DJI_0425.JPG
# 1/1 [==============================] - 0s 208ms/step
# Mask pixel count: 521 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.239908854166666%
# Nome imagem: fotos\DJI_0426.JPG
# 1/1 [==============================] - 0s 227ms/step
# Mask pixel count: 646 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.257161458333334%
# Nome imagem: fotos\DJI_0427.JPG
# 1/1 [==============================] - 0s 250ms/step
# Mask pixel count: 785 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.388346354166667%
# Nome imagem: fotos\DJI_0428.JPG
# 1/1 [==============================] - 0s 287ms/step
# Mask pixel count: 814 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.624348958333333%
# Nome imagem: fotos\DJI_0429.JPG
# 1/1 [==============================] - 0s 235ms/step
# Mask pixel count: 879 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.1533203125%
# Nome imagem: fotos\DJI_0430.JPG
# 1/1 [==============================] - 0s 345ms/step
# Mask pixel count: 881 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.169596354166667%
# Nome imagem: fotos\DJI_0431.JPG
# 1/1 [==============================] - 0s 248ms/step
# Mask pixel count: 974 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.926432291666667%
# Nome imagem: fotos\DJI_0432.JPG
# 1/1 [==============================] - 0s 313ms/step
# Mask pixel count: 975 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.9345703125%
# Nome imagem: fotos\DJI_0433.JPG
# 1/1 [==============================] - 0s 265ms/step
# Mask pixel count: 985 | Image pixel total: 12288
# True: crivo=0.5%, calculado:8.015950520833332%
# Nome imagem: fotos\DJI_0434.JPG
# 1/1 [==============================] - 0s 249ms/step
# Mask pixel count: 1004 | Image pixel total: 12288
# True: crivo=0.5%, calculado:8.170572916666668%
# Nome imagem: fotos\DJI_0435.JPG
# 1/1 [==============================] - 0s 363ms/step
# Mask pixel count: 935 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.609049479166667%
# Nome imagem: fotos\DJI_0436.JPG
# 1/1 [==============================] - 0s 254ms/step
# Mask pixel count: 927 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.5439453125%
# Nome imagem: fotos\DJI_0437.JPG
# 1/1 [==============================] - 0s 223ms/step
# Mask pixel count: 852 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.93359375%
# Nome imagem: fotos\DJI_0438.JPG
# 1/1 [==============================] - 0s 224ms/step
# Mask pixel count: 902 | Image pixel total: 12288
# True: crivo=0.5%, calculado:7.340494791666667%
# Nome imagem: fotos\DJI_0439.JPG
# 1/1 [==============================] - 0s 217ms/step
# Mask pixel count: 831 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.7626953125%
# Nome imagem: fotos\DJI_0440.JPG
# 1/1 [==============================] - 0s 229ms/step
# Mask pixel count: 813 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.6162109375%
# Nome imagem: fotos\DJI_0441.JPG
# 1/1 [==============================] - 0s 208ms/step
# Mask pixel count: 776 | Image pixel total: 12288
# True: crivo=0.5%, calculado:6.315104166666667%
# Nome imagem: fotos\DJI_0442.JPG
# 1/1 [==============================] - 0s 229ms/step
# Mask pixel count: 647 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.265299479166666%
# Nome imagem: fotos\DJI_0443.JPG
# 1/1 [==============================] - 0s 225ms/step
# Mask pixel count: 642 | Image pixel total: 12288
# True: crivo=0.5%, calculado:5.224609375%
# Nome imagem: fotos\DJI_0444.JPG
# 1/1 [==============================] - 0s 207ms/step
# Mask pixel count: 602 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.899088541666666%
# Nome imagem: fotos\DJI_0445.JPG
# 1/1 [==============================] - 0s 196ms/step
# Mask pixel count: 554 | Image pixel total: 12288
# True: crivo=0.5%, calculado:4.508463541666666%
# Nome imagem: fotos\DJI_0446.JPG
# 1/1 [==============================] - 0s 220ms/step
# Mask pixel count: 440 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.5807291666666665%
# Nome imagem: fotos\DJI_0447.JPG
# 1/1 [==============================] - 0s 215ms/step
# Mask pixel count: 386 | Image pixel total: 12288
# True: crivo=0.5%, calculado:3.1412760416666665%
